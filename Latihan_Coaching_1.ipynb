# %% [markdown]
# <a href="https://colab.research.google.com/github/pujii22/pujii22.github.io/blob/main/Latihan_Coaching_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Puji Lestari"
nik = 3204374211020001

print("nama =", nama, "\n","nik =", nik)
# Out:
# nama = Puji Lestari
#  nik = 3204374211020001

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
import csv

dataset = '/content/Drive/Dataset/Tweets.csv'
with open(dataset) as inisial_file:
  baca_file = csv.reader(inisial_file, delimiter=',') 
  for baris in baca_file:
    print(baris)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['569759330662109185', 'negative', '1.0', 'Late Flight', '1.0', 'US Airways', '', 'rossj987', '', '0', '@USAirways not to mention the fact that my flight was delayed BECAUSE YOUR COMPUTERS WERE DOWN', '', '2015-02-22 23:23:04 -0800', 'Washington, D.C.', 'Eastern Time (US & Canada)']
# ['569759291839803392', 'negative', '0.65', 'Flight Booking Problems', '0.3609', 'US Airways', '', 'pronetowander', '', '0', '@USAirways cannot add my frequent flyer number on your website.  Can you help?', '', '2015-02-22 23:22:55 -0800', '', '']
# ['569759259480600577', 'negative', '1.0', 'Customer Service Issue', '0.6894', 'US Airways', '', 'rossj987', '', '0', '@USAirways how do I get off my plane and wait over an hour and a half to speak to someone about reFlight Booking Problems?', '', '2015-02-22 23:22:47 -0800', 'Washington, D.C.', 'Eastern Time (US & Canada)']
# ...

# %%
import pandas as pd 

dataset = pd.read_csv('/content/Drive/Dataset/Tweets.csv')
dataset
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      570306133677760513           neutral                        1.0000
# 1      570301130888122368          positive                        0.3486
# 2      570301083672813571           neutral                        0.6837
# 3      570301031407624196          negative                        1.0000
# 4      570300817074462722          negative                        1.0000
# ...                   ...               ...                           ...
# 14635  569587686496825344          positive                        0.3487
# 14636  569587371693355008          negative                        1.0000
# 14637  569587242672398336           neutral                        1.0000
# 14638  569587188687634433          negative                        1.0000
# 14639  569587140490866689           neutral                        0.6771
#
#                negativereason  negativereason_confidence         airline  \
# ...
